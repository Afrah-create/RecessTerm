# %%
'''
What is a model?
A model is a simplified representation of a system, concept, 
or phenomenon that helps to understand, explain, predict, or 
control its behavior. Models can take various forms, including 
mathematical equations, physical replicas, computer simulations, 
or conceptual frameworks. They are used in various fields such as science, 
engineering, economics, and social sciences to analyze complex systems and make 
informed decisions.
Analogy
y = mx + b
Algorithms

Linear regression, decision trees, neural networks, and clustering algorithms 
are examples of algorithms used in modeling. These algorithms help to identify 
patterns, relationships, and trends within data, allowing for predictions and 
insights to be drawn from the model.

What is regression?
Regression is a statistical method used to model the relationship between 
a dependent variable and one or more independent variables.
What is classification?
Classification is a type of supervised learning in machine 
learning where the goal is to predict the categorical class
# Common types of classification algorithms include logistic
  regression, decision trees, random forests, support vector
  machines, and neural networks. These algorithms analyze labeled 
 data to learn patterns and make predictions about new, unseen data.
# Common types of regression algorithms include linear regression, polynomial
  regression, ridge regression, and lasso regression. These algorithms analyze
  the relationship between variables to make predictions about continuous outcomes.

# key differences between regression and classification:
1. Output Type: Regression predicts continuous numerical values, while 
classification predicts categorical labels or classes.
2. Evaluation Metrics: Regression models are evaluated using metrics such 
as Mean Squared Error (MSE), Root Mean Squared Error (RMSE), and R-squared, 
while classification models are evaluated using metrics like accuracy, precision, 
recall, F1-score, and confusion matrix.

# Workflow of a model
1. Data Collection: Gather relevant data for the problem at hand.
2. Data Preprocessing: Clean and prepare the data, handling missing values, 
outliers, and normalizing or scaling features as needed.
3. Feature Selection/Engineering: Identify and create relevant features that 
will help the model learn patterns in the data.
4. Split the dataset into training and testing sets to evaluate the model's
performance on unseen data.
5. Model Selection: Choose an appropriate algorithm or model type based on the 
problem (regression or classification) and the nature of the data.
6. Model Training: Train the selected model using the prepared dataset, adjusting 
parameters and hyperparameters as necessary.
7. Model testing: Evaluate the model's performance on the testing set to assess its
generalization ability and identify any potential issues such as overfitting or
underfitting.
8. Model Evaluation: Assess the model's performance using appropriate evaluation 
metrics and validation techniques
9. Model tuning: Fine-tune the model by adjusting hyperparameters, feature selection,
or using techniques like cross-validation to improve performance.
10. Model Deployment: Deploy the trained model into a production environment for
real-world use, making predictions on new data and monitoring its performance over time.


# Problems solved using Regression models
1. Predicting house prices based on features like square footage, number of bedrooms,
and location.
2. Forecasting sales revenue based on historical sales data and market trends.
3. Estimating the impact of advertising spend on customer acquisition or sales.
4. Predicting stock prices or financial market trends based on historical data 
and economic indicators.

# Problems solved using Classification models
1. Email spam detection: Classifying emails as spam or not spam based on their 
content and metadata.
2. Medical diagnosis: Classifying patients into different disease categories based 
on their symptoms, test results, and medical history.
3. Customer churn prediction: Identifying customers who are likely to leave a service 
or subscription based on their usage patterns, demographics, and engagement metrics.
4. Sentiment analysis: Classifying text data, such as social media posts or product 
reviews, into positive, negative

# What is overfitting?
Overfitting occurs when a model learns the training data too well, capturing noise
and random fluctuations rather than the underlying patterns. As a result, the model
performs exceptionally well on the training data but poorly on unseen or test data,
indicating that it has failed to generalize. Overfitting can lead to inaccurate
predictions and reduced model performance in real-world scenarios.


# What is underfitting?
Underfitting occurs when a model is too simple to capture the underlying patterns in the data.


# Data collected from the real world?
1. Weather data: Temperature, humidity, wind speed, and precipitation measurements collected 
from weather stations and satellites.
2. Social media data: User posts, comments, likes, shares, and engagement metrics collected 
from platforms like Facebook, Twitter, and Instagram.
3. Financial data: Stock prices, trading volumes, and economic indicators collected from 
financial markets and institutions.
4. Healthcare data: Patient records, medical test results, and treatment outcomes collected 
from hospitals, clinics, and research studies.
5. Transportation data: Traffic flow, vehicle counts, and public transportation usage 
collected from sensors, GPS devices, and transportation agencies.
6. Environmental data: Air quality measurements, water quality data, and pollution 
levels collected from monitoring stations and environmental agencies.
7. Retail data: Sales transactions, customer demographics, and product inventory levels 
collected from point-of-sale systems and e-commerce platforms.
8. Sensor data: Data collected from IoT devices, wearables, and industrial sensors, 
including temperature, pressure, motion, and other environmental parameters.
9. Survey data: Responses from questionnaires and surveys conducted to gather opinions, 
preferences, and feedback from individuals or groups.
10. Geospatial data: Geographic information, satellite imagery, and location-based data 
collected from mapping services, GPS devices, and remote sensing technologies.


# When the say machine Learning?
1. Finding the mean, median, and mode of a dataset.
2. Percentiles and quartiles.
3. Standard deviation and variance.
4. Normal distribution and z-scores.


# Decison tree
A decision tree is a supervised machine learning algorithm used for both classification 
and regression tasks. It works by recursively splitting the data into subsets based on the 
values of input features,


# Confusion matrix
A confusion matrix is a table used to evaluate the performance of a classification model.
# Logistic regression
Logistic regression is a statistical method used for binary classification problems.
# K-nearest neighbors (KNN)
K-nearest neighbors (KNN) is a simple, non-parametric, and instance-based
supervised learning algorithm used for classification and regression tasks.

# Cross-validation
Cross-validation is a model validation technique used to assess the performance and
generalization ability of a machine learning model. It involves partitioning the dataset
into multiple subsets or folds, training the model on some folds, and evaluating it on the
remaining folds. This process is repeated several times, with different folds used for training
and testing, to obtain a more reliable estimate of the model's performance. Cross-validation
helps to mitigate issues like overfitting and provides a better understanding of how the model
will perform on unseen data. Common cross-validation techniques include k-fold cross-validation,
stratified k-fold cross-validation, and leave-one-out cross-validation.

# Area under the curve (AUC)
The area under the curve (AUC) is a performance metric used to evaluate the quality of
binary classification models. It measures the area under the Receiver Operating 
Characteristic curve (ROC) and provides a single scalar value that summarizes the 
model's ability to distinguish between the two classes.
'''
# Out:
# "\nWhat is a model?\nA model is a simplified representation of a system, concept, \nor phenomenon that helps to understand, explain, predict, or \ncontrol its behavior. Models can take various forms, including \nmathematical equations, physical replicas, computer simulations, \nor conceptual frameworks. They are used in various fields such as science, \nengineering, economics, and social sciences to analyze complex systems and make \ninformed decisions.\nAnalogy\ny = mx + b\nAlgorithms\n\nLinear regression, decision trees, neural networks, and clustering algorithms \nare examples of algorithms used in modeling. These algorithms help to identify \npatterns, relationships, and trends within data, allowing for predictions and \ninsights to be drawn from the model.\n\nWhat is regression?\nRegression is a statistical method used to model the relationship between \na dependent variable and one or more independent variables.\nWhat is classification?\nClassification is a type of supervised l
# ...

# %%
# Create a machine leaning model that predicts profits based on sales data(Regression)
# Predicts customer type based on their purchasing behavior(Classification)

# %%
# 1. Import necessary libraries
# 2. Load the dataset and explore the data to understand its structure, features, and target variable.
# 3. Preprocess the data by handling missing values, encoding categorical variables, and scaling numerical features if necessary.
# 4. Split the dataset into training and testing sets to evaluate the model's performance on unseen data.
# 5. Choose an appropriate regression algorithm (e.g., linear regression, decision tree regression, random forest regression) for predicting profits and a classification algorithm (e.g., logistic regression, decision tree classification, random forest classification) for predicting customer type.
# 6. Train the selected models using the training data and evaluate their performance using appropriate metrics (e.g., mean squared error for regression, accuracy, precision, recall for classification).
# 7. Fine-tune the models by adjusting hyperparameters, feature selection, or using techniques like cross-validation to improve performance.

# %%
# 1. Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns # used for data visualization
# Import machine learning libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import mean_squared_error, accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier

# Ignore warnings
#import warnings
#warnings.filterwarnings('ignore')

# %%
# 2. Load the dataset and explore the data to understand its structure, features, and target variable.
# Load the dataset
df = pd.read_csv('ecommerce_bigdata.csv')

# %%
# EDA
df.head()  # Display the first few rows of the dataset
# Out:
#   TransactionID        Date    Region     ProductCategory CustomerType  Sales  \
# 0        TX0001  2026-06-16   Eastern         Electronics    Wholesale   4924
# 1        TX0002  2026-02-12   Central         Electronics       Retail   3283
# 2        TX0003  2026-03-01  Northern                Food       Online   4049
# 3        TX0004  2026-06-03   Western  Household Products       Online   4331
# 4        TX0005  2026-01-21   Western  Household Products       Retail   3283
#
#    Profit
# 0  359.44
# 1  944.32
# 2  967.10
# 3  434.57
# 4  340.48

# %%
# Preprocessing the data
df.info()  # Get information about the dataset, including data types and missing values
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    200 non-null    str
#  1   Date             200 non-null    str
#  2   Region           200 non-null    str
#  3   ProductCategory  200 non-null    str
#  4   CustomerType     200 non-null    str
#  5   Sales            200 non-null    int64
#  6   Profit           200 non-null    float64
# dtypes: float64(1), int64(1), str(5)
# memory usage: 11.1 KB

# %%
# Check for empty rows
empty_rows = df.isnull().all(axis=1).sum()
print("Number of empty rows:", empty_rows)

# Check for duplicate rows
duplicate_rows = df.duplicated().sum()
print("Number of duplicate rows:", duplicate_rows)

# Check for wrong data types
wrong_data_types = df.dtypes[df.dtypes == 'object']
print("Columns with wrong data types:\n", wrong_data_types)

# Check for missing values
missing_values = df.isnull().sum()
print("Missing values in each column:\n", missing_values)

# Drop missing values
df.dropna(inplace=True)
print("Missing values dropped.")
# Out:
# Number of empty rows: 0
# Number of duplicate rows: 0
# Columns with wrong data types:
#  Series([], dtype: object)
# Missing values in each column:
#  TransactionID      0
# Date               0
# Region             0
# ProductCategory    0
# CustomerType       0
# Sales              0
# Profit             0
# dtype: int64
# Missing values dropped.

# %%
# Summary of the dataset
df.describe()  # Get summary statistics of the dataset
# Out:
#              Sales       Profit
# count   200.000000   200.000000
# mean   2567.190000   456.367350
# std    1528.736925   346.853151
# min      56.000000     5.130000
# 25%    1200.500000   173.967500
# 50%    2428.000000   379.330000
# 75%    4052.000000   675.000000
# max    4998.000000  1377.040000

# %%
# Data Visualization

# Setup the plotting style

plt.style.use('seaborn-v0_8-darkgrid')

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# 1 Plot Distribution of Sales

sns.histplot(data=df, x='Sales', bins=30, kde=True, ax=axes[0, 0])

axes[0, 0].set_title('Distribution of Sales')

axes[0, 0].set_xlabel('Sales')

axes[0, 0].set_ylabel('Frequency')

# 2 Plot Distribution of Profit

sns.histplot(data=df, x='Profit', bins=30, kde=True, ax=axes[0, 1])

axes[0, 1].set_title('Distribution of Profit')

axes[0, 1].set_xlabel('Profit')

axes[0, 1].set_ylabel('Frequency')

# 3 Plot Distribution of Customer Type
x = df['Sales']
y = df['ProductCategory']
sns.boxenplot(data=df, y='Sales', x='ProductCategory', ax=axes[1, 0])
axes[1, 0].set_title('Distribution of Sales by Product Category')
axes[1, 0].set_xlabel('Product Category')
axes[1, 0].set_ylabel('Sales')

# Scatter plot of Sales vs Profit
sns.scatterplot(data=df, x='Sales', y='Profit', ax=axes[1, 1])
axes[1, 1].set_title('Sales vs Profit')
axes[1, 1].set_xlabel('Sales')
axes[1, 1].set_ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %%
# Feature engineering: Create a new feature 'ProfitMargin' as Profit/Sales
# create a copy of the original dataframe to avoid SettingWithCopyWarning
df_copy = df.copy()
# Covert date column to datetime format
df_copy['Date'] = pd.to_datetime(df_copy['Date'])
df_copy['Month'] = df_copy['Date'].dt.month
df_copy['Day'] = df_copy['Date'].dt.day
df_copy['Weekday'] = df_copy['Date'].dt.weekday

# %%
from typing import cast, Any
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# 1. Create a dictionary to store your encoders
label_encoder = {}

# 2. Define your categorical columns
categorical_columns = ['Region', 'ProductCategory', 'CustomerType'] 
df_copy = df.copy()  # Ensure your working dataframe is instantiated

# 3. Loop through columns with type-safe transformations
for col in categorical_columns:
    le = LabelEncoder()
    
    # FIX 1: Wrap the raw NumPy array in a pd.Series to satisfy __setitem__
    encoded_array = le.fit_transform(df_copy[col])
    df_copy[col + '_Encoded'] = pd.Series(encoded_array, index=df_copy.index)
    
    # Store the label encoder for future use
    label_encoder[col] = le 
    
    # FIX 2: Explicitly cast the array to a NumPy NDArray so the type checker recognizes .tolist()
    raw_transform = le.transform(le.classes_)
    encoded_list = cast(np.ndarray, raw_transform).tolist()
    
    classes_list = list(le.classes_)
    
    # Create the dictionary cleanly from native Python lists
    mapping = dict(zip(classes_list, encoded_list))
    print(f'Encoded {col}: {mapping}')
df_copy.head()  # Display the first few rows of the modified dataset
# Out:
# Encoded Region: {'Central': 0, 'Eastern': 1, 'Northern': 2, 'Western': 3}
# Encoded ProductCategory: {'Beverages': 0, 'Clothing': 1, 'Electronics': 2, 'Food': 3, 'Household Products': 4}
# Encoded CustomerType: {'Online': 0, 'Retail': 1, 'Wholesale': 2}
#   TransactionID        Date    Region     ProductCategory CustomerType  Sales  \
# 0        TX0001  2026-06-16   Eastern         Electronics    Wholesale   4924
# 1        TX0002  2026-02-12   Central         Electronics       Retail   3283
# 2        TX0003  2026-03-01  Northern                Food       Online   4049
# 3        TX0004  2026-06-03   Western  Household Products       Online   4331
# 4        TX0005  2026-01-21   Western  Household Products       Retail   3283
#
#    Profit  Region_Encoded  ProductCategory_Encoded  CustomerType_Encoded
# 0  359.44               1                        2                     2
# 1  944.32               0                        2                     1
# ...

# %%
# Drop the original categorical columns after encoding (safely)
cols_to_drop = [c for c in ['TransactionID', 'Date', 'ProductCategory', 'CustomerType', 'Region'] if c in df_copy.columns]
if cols_to_drop:
	df_copy.drop(columns=cols_to_drop, inplace=True)
	print(f"Dropped columns: {cols_to_drop}")
else:
	print("No original categorical columns found to drop.")
df_copy.head()  # Display the first few rows of the modified dataset after dropping columns
# Out:
# Dropped columns: ['TransactionID', 'Date', 'ProductCategory', 'CustomerType', 'Region']
#    Sales  Profit  Region_Encoded  ProductCategory_Encoded  \
# 0   4924  359.44               1                        2
# 1   3283  944.32               0                        2
# 2   4049  967.10               2                        3
# 3   4331  434.57               3                        4
# 4   3283  340.48               3                        4
#
#    CustomerType_Encoded
# 0                     2
# 1                     1
# 2                     0
# 3                     0
# 4                     1

# %%
X_reg = df_copy[['Sales']]  # Selecting the 'Sales' column as input
y_reg = df_copy['Profit']                 # Target variable

# Split the dataset into training and testing sets for regression
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(X_reg, y_reg, test_size=0.2, random_state=42)

print("Predicting profits based on sales data (Regression)")
print("Training set size:", X_train_reg.shape)
print("Testing set size:", X_test_reg.shape)
# Out:
# Predicting profits based on sales data (Regression)
# Training set size: (160, 1)
# Testing set size: (40, 1)

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Define the models
regression_models = {
    'Linear Regression': LinearRegression(),
    'Decision Tree Regression': DecisionTreeRegressor(random_state=42),
    'Random Forest Regression': RandomForestRegressor(random_state=42)
}

print("Training and evaluating regression models...")

# Dictionary to collect results cleanly
results_dict = {}

for model_name, model in regression_models.items():
    # 1. Train the model
    model.fit(X_train_reg, y_train_reg)
    
    # 2. Make predictions
    y_pred = model.predict(X_test_reg)
    
    # 3. Calculate metrics
    mse = mean_squared_error(y_test_reg, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test_reg, y_pred)
    
    # 4. Save metrics directly to the dictionary
    results_dict[model_name] = {
        'MSE': mse,
        'RMSE': rmse,
        'R² Score': r2
    }

# --- CLEAN VISUAL PRINTING ---
print("\n" + "="*57)
print("           REGRESSION MODELS PERFORMANCE")
print("="*57)

# Convert results dictionary to a structured DataFrame for perfect tabular formatting
df_results = pd.DataFrame(results_dict).T

# Format the floats so they display with a consistent number of decimal places
print(df_results.round(4))
print("="*57)
# Out:
# Training and evaluating regression models...
# ...
#            REGRESSION MODELS PERFORMANCE
# ...
#                                  MSE      RMSE  R² Score
# Linear Regression         32287.3080  179.6867    0.7142
# Decision Tree Regression  82489.3433  287.2096    0.2698
# Random Forest Regression  53454.4837  231.2023    0.5268
# ...

# %%
# Visualize the performance of the regression models using confusion matrix
from sklearn.metrics import confusion_matrix
fig, axis = plt.subplots(1, 3, figsize=(18, 5))
for i, (model_name, model) in enumerate(regression_models.items()):
    y_pred = model.predict(X_test_reg)
    # For regression, we can visualize the predicted vs actual values
    axis[i].scatter(y_test_reg, y_pred)
    axis[i].plot([y_test_reg.min(), y_test_reg.max()], [y_test_reg.min(), y_test_reg.max()], 'k--', lw=2)
    axis[i].set_title(f'{model_name} Predictions')
    axis[i].set_xlabel('Actual Profit')
    axis[i].set_ylabel('Predicted Profit')
